# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 0.1922
L = 0.858
g = 9.81
M = np.array([4.1, 8.9])
n = np.array([3, 2])

f = (n/L)*np.sqrt((M*g)/m)

p, q = np.polyfit(x, sqrt_T, 1)

plt.errorbar(x, sqrt_T, fmt='o')
plt.plot(x, x*p+q, color='red')
print(f)
plt.show()
# Out:
# [50.58056861 49.6815942 ]
